# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
# find the information about the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
# as we see in the above table we have large number of null values in the category 1 and 2 as well
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %%
df["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df["Occupation"].nunique()
# Out:
# 21

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df["Purchase"].sum()/len(df["Purchase"])
# Out:
# 9333.859852635065

# %%
for column in df.columns:
    print(column, df[column].nunique())
# Out:
# User_ID 5891
# Product_ID 3623
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 17959

# %%
df[df["Gender"] == "M"]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %%
df[df["Gender"] == "F"]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 14      1000006  P00231342      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537472  1004726  P00037142      F  36-45          16             C
# 537473  1004726  P00058442      F  36-45          16             C
# 537474  1004726  P00303242      F  36-45          16             C
# 537475  1004727  P00295942      F    55+           0             C
# 537476  1004727  P00351142      F    55+           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dd_M = len(df[df["Gender"]=="M"])

# %%
dd_f = len(df[df["Gender"]=="F"])

# %%
lst = [dd_M, dd_f]
data_frame = pd.DataFrame({"Ratio" : lst},index = ["Male","Female"])

# %%
data_frame.plot.pie( y = "Ratio", figsize = (6,6),autopct = "%1.2f%%")
# Out:
# <Axes: ylabel='Ratio'>

# %%
# here i have to make a plot between the different age group
df.groupby("Age").size().plot(kind = "bar", figsize = (14,8), title = "Product Purchase by the ages")
# Out:
# <Axes: title={'center': 'Product Purchase by the ages'}, xlabel='Age'>

# %% [markdown]
# ### The above graph will tell the number of buyer are there at different ages groups

# %%
lst = []
for i in df["Age"].unique():
    lst.append([i, df[df["Age"] == i]["Product_ID"].nunique()])
data = pd.DataFrame(lst,columns = ["Age","Product"])

# %%
data.plot.bar(x = "Age")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").sum()["Purchase"].plot(kind = "pie", autopct = "%0.2f%%")
# Out:
# <Axes: ylabel='Purchase'>

# %%
# check the same for their matrial
df.groupby("Marital_Status").size().plot(kind = "pie",autopct = "%2.1f%%")
# Out:
# <Axes: >

# %%
sns.set(rc = {"figure.figsize" : (12,6)} )
sns.countplot(x = "Age", hue = "Gender" , data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby("City_Category").size().plot(kind = "pie", autopct = "%1.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("City_Category").size()
# Out:
# City_Category
# A    144638
# B    226493
# C    166446
# dtype: int64

# %%
sns.set({ "figure.figsize" : (12,6)})
sns.countplot(x = "City_Category", hue = "Age", data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
# do it with the age and marital status
sns.countplot(x = "Marital_Status", hue = "Age", data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = "Age", hue = "Marital_Status", data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"]
# Out:
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370

# %%
sns.countplot(x = "Stay_In_Current_City_Years",hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = "Stay_In_Current_City_Years",hue = "Marital_Status", data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370

# %%
df.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind = "pie", autopct ="%1.2f%%")
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x = df["Occupation"])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").size().sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").sum()["Purchase"].sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x = "Occupation", hue = "Marital_Status", data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").nunique()["Product_ID"].plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").nunique()["Product_ID"].nlargest(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_ID").size().nlargest(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID").sum()["Purchase"].nlargest(10).sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ## Now we are working on the gender and marital status that we have in our dataset

# %%
l = []
for i in range(len(df)):
    l.append(df["Gender"][i] + "_" + str(df["Marital_Status"][i]))

# %%
l
# Out:
# ['F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_1',
#  'F_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
# ...

# %%
df["MaritalGender"] = l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
sns.countplot(x = df["MaritalGender"])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x = "Age", hue = "MaritalGender", data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = "Product_Category_1", hue = "MaritalGender", data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = "Stay_In_Current_City_Years", hue = "MaritalGender", data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = "City_Category", hue = "MaritalGender", data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>
